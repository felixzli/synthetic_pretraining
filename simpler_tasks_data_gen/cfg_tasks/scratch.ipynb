# %%
from nltk import CFG

# %load_ext autoreload
# %reload_ext autoreload
# %autoreload 2
from cfg_utils import *
from generate_cfg_task_data import gen_sent_deriv_given_grammar_and_one_depth

# %%
freeze_causing_rules = ["V0 -> V0 V0 't1'", 'V0 -> V0 V2', "V0 -> 't4' V1", "V2 -> 't3' 't3'", 'V2 -> V0 V2', "V2 -> 't2' 't1'", "V1 -> 't3' V0", "V0 -> 't2'", "V2 -> 't0'", "V1 -> 't1'"]
grammar = CFG.fromstring(freeze_causing_rules)
gen_sent_deriv_given_grammar_and_one_depth(grammar, 2)
# Out:
# (['t2', 't0', 't2', 't3', 't3'],
#  ['V0 -> V0 V2',
#   'V0 -> V0 V2',
#   "V0 -> 't2'",
#   "V2 -> 't0'",
#   'V2 -> V0 V2',
#   "V0 -> 't2'",
#   "V2 -> 't3' 't3'"])

# %%
rules = sample_cfg_rules(8, 5, 5, 3)
rules
# Out:
# ["V0 -> 't1' 't1'",
#  "V0 -> 't4' 't4'",
#  "V0 -> V2 't1'",
#  "V0 -> 't2' V4 V1",
#  "V2 -> V0 't4'",
#  "V0 -> 't2' 't3' V4",
#  "V2 -> 't4' 't3'",
#  'V4 -> V0 V1',
#  "V4 -> 't3'",
#  "V0 -> 't0'",
#  "V1 -> 't1'",
#  "V2 -> 't2'"]

# %%
rules = \
["V0 -> 't1' 't1'",
 "V0 -> 't4' 't4'"]

# %%
grammar = CFG.fromstring(rules)
# print(grammar)
# print(grammar.start())
# parser = make_parser(grammar)

# %%
from generate_specific_depth_sents_and_derivs import generate_specific_depth_sents_and_derivs
generate_specific_depth_sents_and_derivs(grammar, [grammar.start()], 4)
# Out:
# ([], [])

# %%
from generate_specific_depth_returns import f

for sent, deriv in zip(*f(grammar, [grammar.start()], 5)):
  print('----')
  print(sent)
  print(deriv)

# %%
p_rhs = grammar.productions(lhs=grammar.start())[1].rhs()
type(p_rhs)
print(p_rhs)
# Out:
# ('t0', V4)

# %%
sentence= sample_one_sentence_specific_depth(grammar, 4, 100)
print(sentence)
# Out:
# ['t4', 't1', 't4', 't4']

# %%
compute_first_parse(parser, sentence)
# Out:
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# /var/folders/xb/xhwwptys1xs5vn0fn_7c7_600000gn/T/ipykernel_23850/2359936275.py in <module>
# ----> 1 compute_first_parse(parser, sentence)
#
# ~/Documents/research/Universal_LIME/cfg_tasks/cfg_utils.py in compute_first_parse(parser, sentence)
#     105
#     106 def compute_first_parse(parser, sentence):
# --> 107   return compute_parses(parser, sentence, n=1)[0]
#     108
#     109
#
# ~/Documents/research/Universal_LIME/cfg_tasks/cfg_utils.py in compute_parses(parser, sentence, n)
#     112   parsess = []
#     113   i = 0
# --> 114   for p in parser.parse(sentence):
#     115     parsess.append(p)
#     116     i += 1
#
# ~/Documents/research/envs/universal_lime/lib/python3.8/site-packages/nltk/parse/recursivedescent.py in _parse(self, remaining_text, tree, frontier)
# ...

# %%
grammar = CFG.fromstring(rules)
print(grammar.start)
# Out:
# <bound method CFG.start of <Grammar with 10 productions>>

# %%
grammar = CFG.fromstring(rules)
from nltk.parse.generate import generate
for s in generate(grammar, depth=100, n=10):
  print(s)
# Out:
# ['t1', 't0', 't1', 't2']
# ['t1', 't0']
# ['t1', 't1', 't0', 't4']
# ['t1', 't0', 't4']
# ['t1']
# []

# %%
grammar = CFG.fromstring(rules)
from generate_specific_depth import generate_specific_depth
for s in generate_specific_depth(grammar, depth=3, n=10):
    print(s)
  # break
# Out:
# ['t1', 't0', 't1', 't2']
# ['t1', 't0']
# ['t1', 't0', 't4']

# %%
grammar = CFG.fromstring(rules)
from generate_specific_depth import generate_specific_depth
for s in generate_specific_depth(grammar, depth=5, n=10):
    print(s)
  # break
# Out:
# ['t3', 't9', 't1', 't9', 't6', 't9', 't8', 't2', 't2', 't9', 't2', 't2', 't2', 't4', 't6']
# ['t3', 't9', 't1', 't9', 't9', 't2', 't2', 't2', 't4', 't6']
# ['t3', 't9', 't1', 't1', 't6', 't9', 't8', 't2', 't2', 't9', 't2', 't2', 't2', 't4', 't6']
# ['t3', 't9', 't1', 't1', 't9', 't2', 't2', 't2', 't4', 't6']
# ['t3', 't0', 't5', 't6', 't6', 't9', 't8', 't2', 't2', 't0', 't2', 't9', 't8', 't6', 't9', 't8', 't2', 't2', 't9', 't2', 't2', 't2', 't4', 't6']
# ['t3', 't0', 't5', 't6', 't6', 't9', 't8', 't2', 't2', 't0', 't2', 't9', 't8', 't9', 't2', 't2', 't2', 't4', 't6']
# ['t3', 't0', 't5', 't6', 't6', 't9', 't8', 't2', 't2', 't8', 't6', 't9', 't8', 't2', 't2', 't9', 't2', 't2', 't2', 't4', 't6']
# ['t3', 't0', 't5', 't6', 't6', 't9', 't8', 't2', 't2', 't8', 't9', 't2', 't2', 't2', 't4', 't6']
# ['t3', 't0', 't5', 't6', 't0', 't2', 't9', 't8', 't6', 't9', 't8', 't2', 't2', 't9', 't2', 't2', 't2', 't4', 't6']
# ...

# %%
grammar = CFG.fromstring(rules)
from generate_specific_depth import generate_specific_depth
for s in generate_specific_depth(grammar, depth=4, n=10):
  if 'SPECIFIC_DEPTH_REACHED' in s:
    s = list(filter(lambda a: a != 'SPECIFIC_DEPTH_REACHED', s))
    
    print(s)
  # break
# Out:
# ['t3', 't9', 't1', 't6', 't9', 't8', 't2', 't2', 't9', 't2', 't2', 't2', 't4', 't6']
# ['t3', 't9', 't1', 't9', 't2', 't2', 't2', 't4', 't6']
# ['t3', 't0', 't5', 't6', 't8', 't6', 't9', 't8', 't2', 't2', 't9', 't2', 't2', 't2', 't4', 't6']
# ['t3', 't0', 't5', 't6', 't8', 't9', 't2', 't2', 't2', 't4', 't6']
# ['t3', 't6', 't9', 't8', 't2', 't2', 't9', 't2', 't2', 't2', 't4', 't6']
# ['t3', 't9', 't1', 't6', 't9', 't8', 't2', 't2', 't9', 't2', 't2', 't2', 't4', 't0']
# ['t3', 't9', 't1', 't9', 't2', 't2', 't2', 't4', 't0']
# ['t3', 't0', 't5', 't6', 't8', 't6', 't9', 't8', 't2', 't2', 't9', 't2', 't2', 't2', 't4', 't0']

# %%
grammar = CFG.fromstring("""
S -> NP VP
PP -> P NP
NP -> Det N | NP PP
VP -> V NP | VP PP
Det -> 'a' | 'the'
N -> 'dog' | 'cat'
V -> 'chased' | 'sat'
P -> 'on' | 'in'
""")

# %%
grammar.productions()
# Out:
# [S -> NP VP,
#  PP -> P NP,
#  NP -> Det N,
#  NP -> NP PP,
#  VP -> V NP,
#  VP -> VP PP,
#  Det -> 'a',
#  Det -> 'the',
#  N -> 'dog',
#  N -> 'cat',
#  V -> 'chased',
#  V -> 'sat',
#  P -> 'on',
#  P -> 'in']

# %%
grammar = CFG.fromstring("""
S -> 's'
S -> V1 
V1 -> 'x'V1
V1 -> 'x' 
""")

# %%
print(grammar)
# Out:
# Grammar with 4 productions (start state = S)
#     S -> 's'
#     S -> V1
#     V1 -> 'x' V1
#     V1 -> 'x'

# %%
grammar = CFG.fromstring(["S -> 's'", "S -> V1", "V1 -> 'x'V1", "V1 -> 'x'" ])
print(grammar)
# Out:
# Grammar with 4 productions (start state = S)
#     S -> 's'
#     S -> V1
#     V1 -> 'x' V1
#     V1 -> 'x'

# %%
from nltk.parse.generate import generate
for s in generate(grammar, depth=5):
  print(s)
# Out:
# ['s']
# ['x', 'x', 'x']
# ['x', 'x']
# ['x']

# %%
grammar.max_len()
# Out:
# 2

# %%
dir(grammar)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_all_unary_are_lexical',
#  '_calculate_grammar_forms',
#  '_calculate_indexes',
#  '_calculate_leftcorners',
#  '_categories',
#  '_empty_index',
#  '_immediate_leftcorner_categories',
#  '_immediate_leftcorner_words',
#  '_is_lexical',
#  '_is_nonlexical',
#  '_leftcorner_parents',
#  '_leftcorner_words',
#  '_leftcorners',
#  '_lexical_index',
#  '_lhs_index',
#  '_max_len',
#  '_min_len',
#  '_productions',
#  '_rhs_index',
#  '_start',
#  'binarize',
#  'check_coverage',
#  'chomsky_normal_form',
#  'eliminate_start',
#  'fromstring',
#  'is_binarised',
# ...
